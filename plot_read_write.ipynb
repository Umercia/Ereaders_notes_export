# %% [markdown]
# <a href="https://colab.research.google.com/github/Umercia/Ereaders_notes_export/blob/master/plot_read_write.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Gloomhaven Prosperity: 6.3
#
# ### Reputation: 19 (-5 Shop Price)
#
# ### Party Achievements:
# - First Steps
# - Jekserah's Plans
# - Dark Bounty
# - A map to treasure
# - The Voice's Command
# - The Drake's Command
# - Stonebreaker's Censer
# - The Voice's Treasure
# - The Drake's Treasure
# - A Demon's Errand
# - An Invitation
# - The Drake Aided
# - Redhorn's Aid
#
#
#
# ### Global Achievements:
# - City Rule: Militaristic
# - The Merchant Flees
# - The Power of Enhancement
# - Water-Breathing
# - The Rift Neutralized
# - The Edge of Darkness
# - Ancient Technology (4/5)
# - The Voice Freed
# - Artifact: Cleansed (1/3)
# - End of Corruption (2/3)
#
#
# ### Scenario history ([map](https://drive.google.com/file/d/1KQs_PTvyP6J95GoTzFNs1VkpDl3mMYjJ/view?gusp=sharin)):
# - 12/10/2018: Black Barrow (1). Tom, Syl & Mo (New: Brute, Spellweaver, Cragheart. PA: First Steps)
# - 19/10/2018: Borrow Lair (2). Tom, Syl, Mo
# - 26/10/2018: Inox Encampement (3). Tom, Syl, Mo (PA: Jekserah's Plans)
# - 30/10/2018: Magma Pit (63). Syl & Mo
# - 02/11/2018: Crypt of the Damned (4). Syl, Mo
# - 09/11/2018: Glommhaven Warehouse (8). Tom, Syl, Mo (GA: The Merchant Flees)
# - 16/11/2018: Frozen Hollow (14). Tom, Syl, Mo  (retirement: Cragheart-Mo, GA: The Power of Enhancement)
# - 21/11/2018: Chained Isle - fail (70). Tom & Mo (new: Quartermaster-Mo)
# - 28/11/2018: Ruinous Crypt(5). Tom & Mo
# - 05/12/2018: Sunkel Vessel (93). Tom & Mo (one chest left)
# - 14/12/2018: Decaying Crypt (6). Tom & Mo (one chest left. PA: Dark Bounty)
# - 21/12/2018: Drake Nest (43). Tom, Delph(c), Syl, Mo (new: Scoundrel-Delph. GA: Water-Breathing)
# - 29/12/2018: Vibrant Grotto (7). Tom, Delph, Tonio, Mo (new: Mindthief-Tonio. retirement: Spellweaver-Tom)
# - 05/01/2019: Temple of the seer (13). Tom, Delph, Mo(c) (new: Beast Tyran-Tom)
# - 11/05/2019: Necromancer's Sanctum (20). Tom, Delph(c), Syl, Mo (bye bye Jekserah)
# - 18/01/2019: Moutain Pass(16). Tom(c), Delph, Mo
# - 01/02/2019: Echo Chamber (24): Tom, Delph, Syl, Mo(c) (PA: The Voice's Command)
# - 08/02/2019: Icecrag Ascent (25): Tom, Delph, Mo(c) (PA: The Drake's Command; 28xp Tom)
# - 15/02/2019: Forgotten Crypt (19): Tom, Syl(c), Mo (PA:Stonebreaker's Censer, retirement: Brute-Syl)
# - 22/02/2019: Savvas Armory (33): Tom, Syl, Delph, Mo (PA: The Voice's Treasure, The Drake's Treasure, new: Sun-Syl)
# - 01/03/2019: Plane of Elemental Power (10): Tom, Delph, Mo(c) (PA: A Demon's Errand)
# - 30/03/2019:  A Demon's Errand (21): Tom, Delph, Syl(c) Mo (GA: The Rift Neutralized)
# - 05/04/2019: Shrine of Strength (15): Tom, Delph, Syl, Mo
# - 12/04/2019: Outer Ritual Chamber (28): Tom, Delph(c), Mo (PA: An Invitation)
# - 19/04/2019: Abandoned Sewers (18): Syl, Tom, Delph(c), Mo
# - 26/04/2019: Sanctuary of Gloom (29): Syl(c), Tom, Mo (GA: The Edge of Darkness) - New Quest Tom&Syl
# - 18/05/2019: Harrower Hive (76): Syl, Tom, Delph(c), Mo - Hidden scenario
# - 24/05/2019: Arcane library (67): Syl, Tom (GA: Ancient Technology)
# - 31/05/2019: Well of the Unfortunate (69): Tom, Delph, Mo
# - 14/06/2019: Noxious Cellar (52): Tom, Delph, Mo
# - 29/06/2019: Crypt Basement (53): Tom, Syl, Mo(c)
# - 05/07/2019: Palace of Ice (54): Tom, Syl(c), Tony, Mo (retirement: Beast Tyran-Tom +1Pros. + 2Pros (correction for previous retirement))
# - 12/07/2019: Ancient Defense Network (40): Tom, Syl, Mo(c) (GA: Ancient Technology+1)
# - 26/07/2019: Timeworn Tomb (41): Tom, Syl, Delph (+2 Pros, GA: The Voice Freed)
# - 06/09/2019: Temple of the Elements (22): Tom, Delph(c), Mo (GA: Artifact: Recovered)
# - 14/09/2019: Plane of the night (31): Tom(c), Delph, mo (GA: Artifact: Cleaned, -1Pros)
# - 20/09/2019: Oozing Grove (72): Tom, Syl, Mo (+1Pros)
# - 04/10/2019: Slave Pens (38): Tom(c), Delph, Mo (PA: Redhorn's Aid +3Rep)
# - 18/10/2019: Tribal Assault (44): Tom, Mo (+2-1 Rep)
# - 08/11/2019: Shadow Weald (48): Tom(c), Syl, Mo (GA: End of corruption)
# - 11/11/2019. Foggy Thicket (55): Mat, Mo(c) (+1 Rep)
# - 29/11/2019. Bandit's Wood (56): Syl (c), Tom, Mo (+8 Rep, retirement: quartermaster-Mo, sun-Syl)
# - 06/12/2019: Sulfur Mine (65): Syl(new: Orchid), Delph, Mo(new: Beast tyran) (Ancient Technology +1)
# - 13/12/2019: Ancien Citern (26): Syl, Delph(c), Delph (retirement: scoudrel-delph, +2 pros, +1 rep)
# - 10/01/2020: Forgotten Grove (59): Syl, Delph (New: Note), Tom, Mo (+1pros, -1 rep)
# - 18/01/2020: Alchemy Lab (60): Syl, Tom, Mo (+1 pros, +1 rep)
# - 25/01/2020: Doom Trench (37): Delph, Tom (New: Crag), Mo (-2 rep)
# - 31/01/2020: Chained Island (70): Tom (c), Mo (+2 pros, 1 rep)
# - 29/05/2020: Lair of the Unseeing Eye (47): Syl, Delph, Tom, Mo (+1 end of corruption)
#
# ### Records:
# - raw XP: 28 Tom - Icecrag Ascent
# - raw coin: 11 Mo - Forgotten Grove
# - Damage in one turn: 16 Tom - Sanctuary of Gloom
# - Damage out one turn: 24 Delph - Shrine of Strength
#
# ### Other Notes:
#
# - Gain 5 "Ancient Technology" global achievements: 4/5
#     - Open envelope A
# - ~~Have gain both "The Drake's Command" and the "The Drake's Treasure" party achievements~~
#     - ~~add City event 75 and Road Event 66 to the decks, and gain "The Drake Aided" global achievement~~
# - ~~Dontate a total of 10x10 gold to the Sanctuary of the Great Oak: 100/100~~  320/1000
#     - ~~Open envelope B~~
# - ~~Have a party reputation of 10 or higher~~
#     - ~~Open box Sun~~
# - ~~Have party reputation of 20~~
#     - ~~add City event 76 and Road event 67 to the deck~~
# - Have a party reputation of -10 or lower
#     - Open box Moon
# - Have party reputation of -20
#     - add City event 77 and Road event 68 to the deck
# - ~~Retire a character~~
#     - ~~Open the Town Records Book~~
# - [Town records](https://drive.google.com/file/d/1hoyQTz6YQ_TfTm8RQaZE7C2ER1qfFyxH/view?usp=sharing):
#     - ~~Reach prosperity level 3~~
#     - ~~Reach prosperity level 4: Unlock Oozing grove (72)~~
#     - ~~Oozing Grove completed: Add City Event 80~~
#     - ~~Reach prosperity level 5~~
#     - ~~Reach properity level 6: unlock Rockide Ridge (73)~~
#     - Rockide Ridge completed
#     - Reach prosperity level 7: unlock Vault of Secrets (77)
#     - Vault of Secrets completed
#     - Scenario 51 completed
#
# - [Runes](https://photos.app.goo.gl/YgM1w6UXLmLYuLbu5) message:
#     - Mysterious mind flash, Shrine of Strength (15 Savvas temple): "Search for the rise of the decoder ring. Look to the end of word 11 on line 3.""
#     - Message found in the last room, Horrower Hive (76): "We burrow deep but the central clue cannot be fond. It is lost to us. The only thing left to do is ask the creator directly. Send him dust and nothing else."
#     - Stone tablet left by the Voice, Timeworn Tomb (41): "The creator has made a request for our spoils. The twefth letter holds the key"
#     - Road Event (46): 'The Ruins of the deep take shape'
#     - Envelope X: 'we call from the dust from the aged bones of those you have killed. speak our name into his web and we will be free. 10 clues yuo must find. 10 letters to our name. here is our first: B'

# %%
gloom_haven_plot(edges_df, node_carac_df, graph_title="GloomHaven Main Campaign", n_size=700)

# %%
# gloom_haven_plot("sideScenarios.csv", "GloomNodeCarac.csv", "Side Scenarios")
gloom_haven_plot(edges_df_side, node_carac_df, "Side Scenarios", n_size= 700)

# %%
 import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
    
    
def gloom_haven_plot(edges_df_, node_carac_df_, graph_title, n_size=1500):
    """plot network graph from a list of edge ('edge_file') and a list
    of node ('node_file')"""

    # inputs & formating -------------------------------------------------------------------
    df = edges_df_ #pd.read_csv(edge_file)
    carac = node_carac_df_ # pd.read_csv(node_file, index_col="ID")
    network_o = nx.from_pandas_edgelist(df, 'from', 'to',
                                        create_using=nx.Graph())   # network plot object
    
    # extract informations of nodes present in network_o/df/GloomEdgeList.csv
    carac = carac.loc[list(network_o.nodes()), :]
    carac['status'] = pd.Categorical(carac['status'])   # formating color in the graph
    carac['status'].cat.codes

    # extract node positions
    pos = nx.spring_layout(network_o)
    
    # trick: spring_layout(above) work well on nx.Graph() but not with nx.DiGraph(), 
    # so network_o is set up again after pos assignement with create_using=nx.DiGraph()
    # Digraph(): "Direct Graph" is needed to draw arrows.
    network_o = nx.from_pandas_edgelist(df, 'from', 'to',
                                        create_using=nx.DiGraph())   # network plot object

    # frame with node infos (info+positions)
    pos_df = pd.DataFrame(pos, index=("X", "Y")).T
    pos_df.index.name = "ID"
    node_info = pd.merge(pos_df, carac, left_index=True, right_index=True)

    node_labels = {}             # dict format needed
    for i in node_info.index.values:
        node_labels[i] = i

    # plot -----------------------------------------------------------------------------------
    plt.figure(figsize=(12, 10))
    rednodes = list(node_info[node_info["status"] == "Done"].index)
    bluenodes = list(node_info[node_info["status"] == "Open"].index)
    greennodes = list(node_info[node_info["status"] == "Close"].index)

    #nx.draw_networkx_nodes
    nx.draw(network_o, pos=pos, nodelist=rednodes,
            node_color='#009E8E', label='Done', node_size=n_size,
            alpha=1, arrowstyle="->", arrowsize=30, width=3)
    nx.draw(network_o, pos=pos, nodelist=bluenodes,
                           node_color='#FFA500', label='Open', node_size=n_size,
                           alpha=1, arrowstyle="->", arrowsize=30)
    nx.draw(network_o, pos=pos, nodelist=greennodes,
                           node_color='#F80012', label='Close', node_size=n_size,
                           alpha=1, arrowstyle="->", arrowsize=30)    
    nx.draw_networkx_labels(network_o, pos, node_labels, font_size=16)
    
    # text
    for i in node_info.index:   # plt.text() does not accept arrays as inputs: loop needed
        x = node_info.loc[i, "X"]
        y = node_info.loc[i, "Y"]
        title = node_info.loc[i, "title"]
        text_distance = 0.1*n_size/2000
        plt.text(x, y-text_distance,
                 s=title,
                 bbox=dict(facecolor='orange', alpha=0.3),
                 horizontalalignment='center',
                 size=9)

    plt.title(graph_title, size=18, fontweight="bold")
    plt.axis('off')
    plt.legend(bbox_to_anchor=(0.9, 0.0),
               fancybox=False, shadow=False, ncol=3, prop={'size': 20})
    plt.show();

# %%
# Data
import pandas as pd

# edges_df main campaign
edges_df = pd.DataFrame(
[[1,2],
[2,3],
[2,4],
[3,8],
[3,9],
[4,6],
[4,5],
[6,8],
[7,20],
[8,7],
[8,13],
[8,14],
[10,21],
[10,22],
[13,15],
[14,19],
[14,31],
[14,43],
[14,7],
[16,24],
[16,25],
[18,14],
[18,23],
[18,26],
[18,43],
[5,10],
[5,14],
[5,19],
[19,27],
[20,16],
[20,18],
[20,28],
[22,31],
[22,35],
[22,36],
[24,30],
[24,32],
[25,33],
[25,34],
[26,22],
[28,29],
[31,37],
[31,38],
[31,39],
[31,43],
[33,40],
[37,47],
[38,44],
[38,48],
[40,41],
[43,26],
[43,37],
[47,51],
[48,51]],
    
columns = ["from","to"])

# edges_df side scenarios
edges_df_side = pd.DataFrame(
[[0,52],
[52,53],
[53,54],
[55,56],
[59,60],
[0,17],
[0,64],
[0,65],
[0,63],
[0,67],
[0,69],
[0,70],
[0,72],
[0,73],
[0,76],
[0,93],
[0,94],
[0,55],
[0,59],
[0,82], 
 ],
columns = ["from","to"])


# GloomNodeCarac
node_carac_df = pd.DataFrame(
[[0,"Close","Others"],
[1,"Done","Black Barrow"],
[2,"Done","Barrow Lair"],
[63,"Done","Magma pit"],
[3,"Done","Inox Encampement"],
[4,"Done","Crypt of the Damned"],
[5,"Done","Ruinous Crypt"],
[6,"Done","Decaying Crypt"],
[8,"Done","Gloomhaven Warehouse"],
[9,"Close","Diamond Mine"],
[7,"Done","Vibrant Grotto"],
[10,"Done", "Plane of Elemental Power"],
[13,"Done","Temple of the Seer"],
[14,"Done","Frozen Hollow"],
[15,"Done","Shrine of Strength"],
[16,"Done", "Mountain Pass"],
[18,"Done","Abandoned Sewers"],
[17,"Open","Lost Island"],
[19,"Done","Forgotten Crypt"],
[20,"Done","Necromancer's Sanctum"],
[21,"Done","Infernal Throne"],
[22,"Done","Temple of the Elements"],
[24,"Done","Echo Chamber"],
[23,"Open","Deep Ruins"],
[25,"Done","Icecrag Ascent"],
[26,"Done","Ancien Citern"],
[27,"Open","Ruinous Rift"],
[28,"Done","Outer Ritual Chamber"],
[29,"Done","Sanctuary of Gloom"],
[30,"Open","Shrine of the Depths"],
[31,"Done","Plane of Night"],
[32,"Open","Decrepit Wood"],
[33,"Done","Savvas Armory"],
[34,"Close","Scorched Summit"],
[35,"Close","Glommhaven Battlements A"],
[36,"Close","Glommhaven Battlements B"],
[37,"Done","Doom Trench"],
[38,"Done","Slave Pens"],
[39,"Open","Treacherous Divide"],
[40,"Done","Ancient Defense Network"],
[41,"Done","Timeworn Tomb"],
[43,"Done","Drake Nest"],
[44,"Done","Tribal Assault"],
[47,"Done","Lair of the Unseeing Eye"],
[48,"Done","Shadow Weald"],
[51,"Open","The Void"],
[52,"Done","Noxious Cellar"],
[53,"Done","Crypt Basement"],
[54,"Done","Palace of Ice"],
[55,"Done","Foggy Thicket"],
[56,"Done","Bandit's Wood"],
[59,"Done","Forgotten Groove"],
[60,"Done","Alchemy Lab"],
[64,"Open","Arcane Underwater Lagoon"],
[65,"Done","Sulfur Mine"],
[67,"Done","Arcane Library"],
[69,"Done","Well of the Unfortunate"],
[70,"Done","Chained Isle"],
[72,"Done","Oozing Grove"],
[73,"Open","Rockide Ridge"],
[76,"Done","Harrower Hive"],
[82,"Open","Temple of the Eclipse"],
[93,"Done","Sunken Vessel"],
[94,"Open","Vermling Nest"]],
columns = ["ID","status","title"])

node_carac_df.set_index("ID", inplace=True)
